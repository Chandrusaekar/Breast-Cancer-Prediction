# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r'C:\Users\VINOTHKUMAR\Desktop\codes\My Work\Datasets_Cancer.csv',sep=',')

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'benign_0__mal_1'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# benign_0__mal_1            0
# dtype: int64

# %%
data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data[data['benign_0__mal_1']==0].describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   212.000000    212.000000      212.000000   212.000000
# mean     17.462830     21.604906      115.365377   978.376415
# std       3.203971      3.779470       21.854653   367.937978
# min      10.950000     10.380000       71.900000   361.600000
# 25%      15.075000     19.327500       98.745000   705.300000
# 50%      17.325000     21.460000      114.200000   932.000000
# 75%      19.590000     23.765000      129.925000  1203.750000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       212.000000        212.000000      212.000000           212.000000
# mean          0.102898          0.145188        0.160775             0.087990
# std           0.012608          0.053987        0.075019             0.034374
# min           0.073710          0.046050        0.023980             0.020310
# ...

# %%
data[data['benign_0__mal_1']==1].describe()
# Out:
#        mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# count   357.000000    357.000000      357.000000  357.000000       357.000000
# mean     12.146524     17.914762       78.075406  462.790196         0.092478
# std       1.780512      3.995125       11.807438  134.287118         0.013446
# min       6.981000      9.710000       43.790000  143.500000         0.052630
# 25%      11.080000     15.150000       70.870000  378.200000         0.083060
# 50%      12.200000     17.390000       78.180000  458.400000         0.090760
# 75%      13.370000     19.760000       86.100000  551.100000         0.100700
# max      17.850000     33.810000      114.600000  992.100000         0.163400
#
#        mean compactness  mean concavity  mean concave points  mean symmetry  \
# count        357.000000      357.000000           357.000000     357.000000
# mean           0.080085        0.046058             0.025717       0.174186
# ...

# %%
data.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
y=data['benign_0__mal_1']

# %%
x=data.drop('benign_0__mal_1',axis=1)

# %%
x.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='object')

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: benign_0__mal_1, Length: 569, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ###  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logr = LogisticRegression()

# %%
model1=logr.fit(x_train, y_train)

# %%
y_pred=model1.predict(x_test)

# %%
print("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.947368

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
model2=knn.fit(x_train, y_train)

# %%
y_pred=model2.predict(x_test)

# %%
print("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.938596

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
model3=gnb.fit(x_train,y_train)

# %%
y_pred=model3.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.929825

# %% [markdown]
# ### Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
model4=dtc.fit(x_train,y_train)

# %%
y_pred=model4.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.912281

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
model5=rfc.fit(x_train,y_train)

# %%
y_pred = model5.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.982456

# %% [markdown]
# ### Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
model7=dtc.fit(x_train, y_train)

# %%
y_pred = model7.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.912281

# %% [markdown]
# ### XG BOOST  - BASE MODEL

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
model6=xgb.fit(x_train, y_train)

# %%
y_pred = model6.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.973684

# %% [markdown]
# ### log reg, Ran forest....hyper parameter tuning..

# %% [markdown]
# ## Random Forest - Hyper-parameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rfrs = RandomForestClassifier()

# %%
hpar_sel ={'n_estimators': [600,700,800], 'criterion':['entropy','gini'], 'max_features': ['auto', 'sqrt'],
           'min_samples_leaf': [0.75,1,1.25], 'min_samples_split': [4,5,6],'max_depth':[6,7,8]
    }
search = RandomizedSearchCV(rfrs, hpar_sel, cv=5)
search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [6, 7, 8],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [0.75, 1, 1.25],
#                                         'min_samples_split': [4, 5, 6],
#                                         'n_estimators': [600, 700, 800]})

# %%
search.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 7,
#  'criterion': 'gini'}

# %%
search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=7, min_samples_split=4, n_estimators=700)

# %%
modela=search.best_estimator_.fit(x_train, y_train)

# %%
y_pred = modela.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.956140

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfgs = RandomForestClassifier()

# %%
hpar_sel1 = {'n_estimators': [700,750,800], 'criterion':['entropy','gini'], 'max_features': ['auto', 'sqrt'],
           'min_samples_leaf': [1,2], 'min_samples_split': [4],'max_depth':[8,9,10]
    }
search = GridSearchCV(rfgs, hpar_sel1, cv=5)
search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [8, 9, 10],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2], 'min_samples_split': [4],
#                          'n_estimators': [700, 750, 800]})

# %%
search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'n_estimators': 700}

# %%
modela=search.best_estimator_.fit(x_train, y_train)

# %%
y_pred = modela.predict(x_test)

# %%
print ("Number of mislabeled points out of a total %d points : %f"
      % (x_test.shape[0],((y_test == y_pred).sum())/x_test.shape[0]))
# Out:
# Number of mislabeled points out of a total 114 points : 0.956140

# %%
from sklearn.model_selection import cross_val_score

# %%
print((cross_val_score(rfc, x_train, y_train, cv=10,)))
# Out:
# [1.         0.95652174 0.97826087 0.93478261 0.93478261 0.95555556
#  1.         0.91111111 1.         0.95555556]

# %%
print(np.mean((cross_val_score(rfc, x_train, y_train, cv=10,))))
# Out:
# 0.9604830917874396

# %%
print(np.mean(cross_val_score(rfc, x_train, y_train, cv=10)))
# Out:
# 0.9648309178743961

# %%
print((cross_val_score(rfc, x_train, y_train, cv=10)))
# Out:
# [1.         0.95652174 0.97826087 0.93478261 0.91304348 0.95555556
#  0.97777778 0.91111111 0.97777778 0.97777778]

# %%
from sklearn.metrics import roc_curve, auc

# %%
y_score=modela.predict_proba(x_test)
y_pred=modela.predict(x_test)

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# %%
roc_auc
# Out:
# 0.971260717688155

# %%
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## To Pickle File and Deploy

# %%
modela
# Out:
# RandomForestClassifier(max_depth=7, min_samples_split=4, n_estimators=700)

# %%
import pickle


file_Name = "Cancer.pkl"
# open the file for writing
fileObject = open(file_Name,'wb') 

# this writes the object a to the
# file named 'testfile'
pickle.dump(modela,fileObject,protocol=2)   

# here we close the fileObject
fileObject.close()

# %%
# we open the file for reading
fileObject = open(file_Name,'rb')  
# load the object from the file into var b
model = pickle.load(fileObject)  
out = model.predict([np.array(x.iloc[1])])
out[0]
# Out:
# 0

# %%
np.array(x.iloc[0])
# Out:
# array([1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#        3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#        8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#        3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#        1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01])

# %%
len(list(x.columns))
# Out:
# 30

# %%
x.head(2)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
#
#    worst concave points  worst symmetry  worst fractal dimension
# ...
